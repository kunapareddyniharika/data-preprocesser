# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Gopi Raju\\Desktop\\remote internship\\dataset'

# %%
os.chdir("C:\\Users\\Gopi Raju\\Desktop\\remote internship\\dataset")
os.getcwd()
# Out:
# 'C:\\Users\\Gopi Raju\\Desktop\\remote internship\\dataset'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv("cereal.csv")
data
# Out:
#                           name mfr type  calories  protein  fat  sodium  \
# 0                    100% Bran   N    C        70      4.0  1.0     130
# 1            100% Natural Bran   Q    C       120      3.0  5.0      15
# 2                     All-Bran   K    C        70      4.0  1.0     260
# 3    All-Bran with Extra Fiber   K    C        50      4.0  0.0     140
# 4               Almond Delight   R    C       110      2.0  2.0     200
# ..                         ...  ..  ...       ...      ...  ...     ...
# 96                        Trix   G    C       110      1.0  1.0     140
# 97                Waffle Crisp   K    C       110      2.0  1.0     165
# 98                  Wheat Chex   R    C       100      3.0  1.0     230
# 99                    Wheaties   G    C       100      3.0  1.0     200
# 100        Wheaties Honey Gold   G    C       110      2.0  1.0     200
#
#      fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     10.0    5.0     6.0     280        25      3     1.0  0.33  68.402973
# 1      2.0    8.0     8.0     135         0      3     1.0  1.00  33.983679
# 2      9.0    7.0     5.0     320        25      3     1.0  0.33  59.425505
# 3     14.0    8.0     0.0     330        25      3     1.0  0.50  93.704912
# 4      1.0   14.0     8.0      -1        25      3     1.0  0.75  34.384843
# ..     ...    ...     ...     ...       ...    ...     ...   ...        ...
# 96     0.0   13.0    12.0      25        25      2     1.0  1.00  27.753301
# 97     3.2   28.0     2.0      75        25      2     1.0  1.00  34.325100
# 98     3.0   17.0     3.0     115        25      1     1.0  0.67  49.787445
# 99     3.0   17.0     3.0     110        25      1     1.0  1.00  51.592193
# 100    1.0   16.0     8.0      60        25      1     1.0  0.75  36.187559
#
# [101 rows x 16 columns]

# %%
data.isnull().any()
# Out:
# name        False
# mfr         False
# type        False
# calories    False
# protein     False
# fat         False
# sodium      False
# fiber       False
# carbo       False
# sugars      False
# potass      False
# vitamins    False
# shelf       False
# weight      False
# cups        False
# rating      False
# dtype: bool

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_x=LabelEncoder()
data['name']=labelencoder_x.fit_transform(data['name'])

# %%
data
# Out:
#      name mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 0       0   N    C        70      4.0  1.0     130   10.0    5.0     6.0
# 1       1   Q    C       120      3.0  5.0      15    2.0    8.0     8.0
# 2       2   K    C        70      4.0  1.0     260    9.0    7.0     5.0
# 3       3   K    C        50      4.0  0.0     140   14.0    8.0     0.0
# 4       4   R    C       110      2.0  2.0     200    1.0   14.0     8.0
# ..    ...  ..  ...       ...      ...  ...     ...    ...    ...     ...
# 96     96   G    C       110      1.0  1.0     140    0.0   13.0    12.0
# 97     97   K    C       110      2.0  1.0     165    3.2   28.0     2.0
# 98     98   R    C       100      3.0  1.0     230    3.0   17.0     3.0
# 99     99   G    C       100      3.0  1.0     200    3.0   17.0     3.0
# 100   100   G    C       110      2.0  1.0     200    1.0   16.0     8.0
#
#      potass  vitamins  shelf  weight  cups     rating
# 0       280        25      3     1.0  0.33  68.402973
# 1       135         0      3     1.0  1.00  33.983679
# 2       320        25      3     1.0  0.33  59.425505
# 3       330        25      3     1.0  0.50  93.704912
# 4        -1        25      3     1.0  0.75  34.384843
# ..      ...       ...    ...     ...   ...        ...
# 96       25        25      2     1.0  1.00  27.753301
# 97       75        25      2     1.0  1.00  34.325100
# 98      115        25      1     1.0  0.67  49.787445
# 99      110        25      1     1.0  1.00  51.592193
# 100      60        25      1     1.0  0.75  36.187559
#
# [101 rows x 16 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f00231d49596> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
#
# NameError: name 'x' is not defined

# %%
x=data.iloc[:,0:3].values

y=data.iloc[:,3].values

# %%
x,y
# Out:
# (array([[0, 'N', 'C'],
#         [1, 'Q', 'C'],
#         [2, 'K', 'C'],
#         [3, 'K', 'C'],
#         [4, 'R', 'C'],
#         [5, 'R', 'C'],
#         [6, 'G', 'C'],
#         [7, 'K', 'C'],
#         [8, 'G', 'C'],
#         [9, 'G', 'C'],
#         [10, 'R', 'C'],
#         [11, 'P', 'C'],
#         [12, 'A', 'C'],
#         [13, 'A', 'H'],
#         [14, 'Q', 'C'],
#         [15, 'G', 'C'],
#         [16, 'A', 'C'],
#         [17, 'G', 'C'],
#         [18, 'G', 'C'],
#         [19, 'G', 'C'],
#         [20, 'R', 'C'],
#         [21, 'K', 'C'],
#         [22, 'K', 'C'],
#         [23, 'G', 'C'],
#         [24, 'K', 'C'],
#         [25, 'N', 'H'],
#         [26, 'K', 'C'],
#         [27, 'G', 'C'],
#         [28, 'A', 'C'],
#         [29, 'R', 'C'],
#         [30, 'Q', 'C'],
#         [31, 'R', 'C'],
#         [32, 'K', 'C'],
#         [33, 'K', 'C'],
#         [34, 'K', 'C'],
#         [35, 'P', 'C'],
#         [36, 'K', 'C'],
#         [37, 'P', 'C'],
#         [38, 'P', 'C'],
#         [39, 'G', 'C'],
#         [40, 'P', 'C'],
#         [41, 'P', 'C'],
#         [42, 'P', 'C'],
#         [43, 'N', 'C'],
#         [44, 'Q', 'C'],
#         [45, 'G', 'C'],
#         [46, 'P', 'C'],
#         [47, 'K', 'C'],
#         [48, 'K', 'C'],
#         [49, 'G', 'C'],
#         [50, 'Q', 'C'],
#         [51, 'G', 'C'],
#         [52, 'G', 'C'],
#         [53, 'A', 'H'],
#         [54, 'G', 'C'],
#         [55, 'R', 'C'],
#         [56, 'R', 'C'],
#         [57, 'K', 'C'],
#         [58, 'G', 'C'],
#         [59, 'K', 'C'],
#         [60, 'K', 'C'],
#         [61, 'K', 'C'],
#         [62, 'G', 'C'],
#         [63, 'A', 'C'],
#         [64, 'P', 'C'],
#         [65, 'K', 'C'],
#         [66, 'K', 'C'],
#         [67, 'Q', 'C'],
#         [68, 'Q', 'C'],
#         [69, 'Q', 'C'],
#         [70, 'Q', 'H'],
#         [71, 'N', 'C'],
#         [72, 'P', 'H'],
#         [73, 'K', 'C'],
#         [74, 'G', 'C'],
#         [75, 'K', 'C'],
#         [76, 'R', 'C'],
#         [77, 'K', 'C'],
#         [78, 'R', 'C'],
#         [79, 'A', 'C'],
#         [80, 'R', 'H'],
#         [81, 'A', 'C'],
#         [82, 'N', 'C'],
#         [83, 'N', 'C'],
#         [84, 'N', 'C'],
#         [85, 'K', 'C'],
#         [86, 'G', 'C'],
#         [87, 'K', 'C'],
#         [88, 'G', 'C'],
#         [89, 'N', 'C'],
#         [90, 'K', 'C'],
#         [91, 'G', 'C'],
#         [92, 'G', 'C'],
#         [93, 'G', 'C'],
#         [94, 'G', 'C'],
#         [95, 'P', 'C'],
#         [96, 'G', 'C'],
#         [97, 'K', 'C'],
#         [98, 'R', 'C'],
#         [99, 'G', 'C'],
#         [100, 'G', 'C']], dtype=object),
#  array([ 70, 120,  70,  50, 110, 165, 110, 110, 193, 130,  90,  90,  82,
#         150, 120, 110, 130, 120, 110, 110, 110, 100, 110, 110, 110, 100,
#         110, 100, 210, 100, 160, 220, 110, 110, 100, 120, 120, 110, 100,
#         110, 100, 110, 120, 150, 120, 110, 110, 110, 140, 110, 100, 110,
#         250, 100, 207, 150, 150, 160, 100, 120, 140,  90, 130,  47, 120,
#         100, 100,  50,  50, 100, 100, 160, 100, 120, 100,  90, 110, 110,
#          95, 250,  90, 140,  80,  90,  90, 110, 155, 110, 120,  90, 155,
#         110, 140, 100, 110, 140, 110, 110, 100, 100, 110], dtype=int64))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[62, 'G', 'C'],
#        [3, 'K', 'C'],
#        [71, 'N', 'C'],
#        [45, 'G', 'C'],
#        [48, 'K', 'C'],
#        [6, 'G', 'C'],
#        [100, 'G', 'C'],
#        [82, 'N', 'C'],
#        [76, 'R', 'C'],
#        [60, 'K', 'C'],
#        [80, 'R', 'H'],
#        [91, 'G', 'C'],
#        [68, 'Q', 'C'],
#        [51, 'G', 'C'],
#        [27, 'G', 'C'],
#        [18, 'G', 'C'],
#        [56, 'R', 'C'],
#        [63, 'A', 'C'],
#        [74, 'G', 'C'],
#        [1, 'Q', 'C'],
#        [61, 'K', 'C'],
#        [42, 'P', 'C'],
#        [41, 'P', 'C'],
#        [4, 'R', 'C'],
#        [15, 'G', 'C'],
#        [17, 'G', 'C'],
#        [40, 'P', 'C'],
#        [38, 'P', 'C'],
#        [5, 'R', 'C'],
#        [92, 'G', 'C'],
#        [59, 'K', 'C'],
#        [0, 'N', 'C'],
#        [34, 'K', 'C'],
#        [28, 'A', 'C'],
#        [50, 'Q', 'C'],
#        [11, 'P', 'C'],
#        [35, 'P', 'C'],
#        [23, 'G', 'C'],
#        [52, 'G', 'C'],
#        [10, 'R', 'C'],
#        [31, 'R', 'C'],
#        [66, 'K', 'C'],
#        [57, 'K', 'C'],
#        [79, 'A', 'C'],
#        [85, 'K', 'C'],
#        [32, 'K', 'C'],
#        [84, 'N', 'C'],
#        [14, 'Q', 'C'],
#        [90, 'K', 'C'],
#        [19, 'G', 'C'],
#        [29, 'R', 'C'],
#        [49, 'G', 'C'],
#        [98, 'R', 'C'],
#        [99, 'G', 'C'],
#        [69, 'Q', 'C'],
#        [20, 'R', 'C'],
#        [95, 'P', 'C'],
#        [72, 'P', 'H'],
#        [77, 'K', 'C'],
#        [25, 'N', 'H'],
#        [37, 'P', 'C'],
#        [81, 'A', 'C'],
#        [46, 'P', 'C'],
#        [39, 'G', 'C'],
#        [65, 'K', 'C'],
#        [58, 'G', 'C'],
#        [12, 'A', 'C'],
#        [89, 'N', 'C'],
#        [88, 'G', 'C'],
#        [70, 'Q', 'H'],
#        [87, 'K', 'C'],
#        [36, 'K', 'C'],
#        [21, 'K', 'C'],
#        [83, 'N', 'C'],
#        [9, 'G', 'C'],
#        [97, 'K', 'C'],
#        [67, 'Q', 'C'],
#        [64, 'P', 'C'],
#        [47, 'K', 'C'],
#        [44, 'Q', 'C']], dtype=object)

# %%
x_test
# Out:
# array([[26, 'K', 'C'],
#        [86, 'G', 'C'],
#        [2, 'K', 'C'],
#        [55, 'R', 'C'],
#        [75, 'K', 'C'],
#        [94, 'G', 'C'],
#        [16, 'A', 'C'],
#        [73, 'K', 'C'],
#        [54, 'G', 'C'],
#        [96, 'G', 'C'],
#        [53, 'A', 'H'],
#        [93, 'G', 'C'],
#        [78, 'R', 'C'],
#        [13, 'A', 'H'],
#        [7, 'K', 'C'],
#        [30, 'Q', 'C'],
#        [22, 'K', 'C'],
#        [24, 'K', 'C'],
#        [33, 'K', 'C'],
#        [8, 'G', 'C'],
#        [43, 'N', 'C']], dtype=object)

# %%
y_train
# Out:
# array([130,  50, 160, 110, 140, 110, 110,  80, 110, 140,  90, 110,  50,
#        110, 100, 110, 150,  47, 100, 120,  90, 120, 110, 110, 110, 120,
#        100, 100, 165, 140, 120,  70, 100, 210, 100,  90, 120, 110, 250,
#         90, 220, 100, 160, 250, 110, 110,  90, 120, 155, 110, 100, 110,
#        100, 100, 100, 110, 140, 100, 110, 100, 110, 140, 110, 110, 100,
#        100,  82,  90, 120, 100, 110, 120, 100,  90, 130, 110,  50, 120,
#        110, 120], dtype=int64)

# %%
y_test
# Out:
# array([110, 155,  70, 150,  90, 110, 130, 120, 207, 110, 100, 100,  95,
#        150, 110, 160, 110, 110, 110, 193, 150], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc1=StandardScaler()
x_train=sc1.fit_transform(x_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-ba1b849512b0> in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc1=StandardScaler()
# ----> 3 x_train=sc1.fit_transform(x_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     551         if y is None:
#     552             # fit method of arity 1 (unsupervised transformation)
# --> 553             return self.fit(X, **fit_params).transform(X)
#     554         else:
#     555             # fit method of arity 2 (supervised transformation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     637         # Reset internal state before fitting
#     638         self._reset()
# --> 639         return self.partial_fit(X, y)
#     640
#     641     def partial_fit(self, X, y=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in partial_fit(self, X, y)
#     661         X = check_array(X, accept_sparse=('csr', 'csc'), copy=self.copy,
#     662                         estimator=self, dtype=FLOAT_DTYPES,
# --> 663                         force_all_finite='allow-nan')
#     664
#     665         # Even in the case of `with_mean=False`, we update the mean anyway
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     494             try:
#     495                 warnings.simplefilter('error', ComplexWarning)
# --> 496                 array = np.asarray(array, dtype=dtype, order=order)
#     497             except ComplexWarning:
#     498                 raise ValueError("Complex data not supported\n"
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'G'

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train,x_test,y_train,y_test
# Out:
# (array([[62, 'G', 'C'],
#         [3, 'K', 'C'],
#         [71, 'N', 'C'],
#         [45, 'G', 'C'],
#         [48, 'K', 'C'],
#         [6, 'G', 'C'],
#         [100, 'G', 'C'],
#         [82, 'N', 'C'],
#         [76, 'R', 'C'],
#         [60, 'K', 'C'],
#         [80, 'R', 'H'],
#         [91, 'G', 'C'],
#         [68, 'Q', 'C'],
#         [51, 'G', 'C'],
#         [27, 'G', 'C'],
#         [18, 'G', 'C'],
#         [56, 'R', 'C'],
#         [63, 'A', 'C'],
#         [74, 'G', 'C'],
#         [1, 'Q', 'C'],
#         [61, 'K', 'C'],
#         [42, 'P', 'C'],
#         [41, 'P', 'C'],
#         [4, 'R', 'C'],
#         [15, 'G', 'C'],
#         [17, 'G', 'C'],
#         [40, 'P', 'C'],
#         [38, 'P', 'C'],
#         [5, 'R', 'C'],
#         [92, 'G', 'C'],
#         [59, 'K', 'C'],
#         [0, 'N', 'C'],
#         [34, 'K', 'C'],
#         [28, 'A', 'C'],
#         [50, 'Q', 'C'],
#         [11, 'P', 'C'],
#         [35, 'P', 'C'],
#         [23, 'G', 'C'],
#         [52, 'G', 'C'],
#         [10, 'R', 'C'],
#         [31, 'R', 'C'],
#         [66, 'K', 'C'],
#         [57, 'K', 'C'],
#         [79, 'A', 'C'],
#         [85, 'K', 'C'],
#         [32, 'K', 'C'],
#         [84, 'N', 'C'],
#         [14, 'Q', 'C'],
#         [90, 'K', 'C'],
#         [19, 'G', 'C'],
#         [29, 'R', 'C'],
#         [49, 'G', 'C'],
#         [98, 'R', 'C'],
#         [99, 'G', 'C'],
#         [69, 'Q', 'C'],
#         [20, 'R', 'C'],
#         [95, 'P', 'C'],
#         [72, 'P', 'H'],
#         [77, 'K', 'C'],
#         [25, 'N', 'H'],
#         [37, 'P', 'C'],
#         [81, 'A', 'C'],
#         [46, 'P', 'C'],
#         [39, 'G', 'C'],
#         [65, 'K', 'C'],
#         [58, 'G', 'C'],
#         [12, 'A', 'C'],
#         [89, 'N', 'C'],
#         [88, 'G', 'C'],
#         [70, 'Q', 'H'],
#         [87, 'K', 'C'],
#         [36, 'K', 'C'],
#         [21, 'K', 'C'],
#         [83, 'N', 'C'],
#         [9, 'G', 'C'],
#         [97, 'K', 'C'],
#         [67, 'Q', 'C'],
#         [64, 'P', 'C'],
#         [47, 'K', 'C'],
#         [44, 'Q', 'C']], dtype=object),
#  array([[26, 'K', 'C'],
#         [86, 'G', 'C'],
#         [2, 'K', 'C'],
#         [55, 'R', 'C'],
#         [75, 'K', 'C'],
#         [94, 'G', 'C'],
#         [16, 'A', 'C'],
#         [73, 'K', 'C'],
#         [54, 'G', 'C'],
#         [96, 'G', 'C'],
#         [53, 'A', 'H'],
#         [93, 'G', 'C'],
#         [78, 'R', 'C'],
#         [13, 'A', 'H'],
#         [7, 'K', 'C'],
#         [30, 'Q', 'C'],
#         [22, 'K', 'C'],
#         [24, 'K', 'C'],
#         [33, 'K', 'C'],
#         [8, 'G', 'C'],
#         [43, 'N', 'C']], dtype=object),
#  array([130,  50, 160, 110, 140, 110, 110,  80, 110, 140,  90, 110,  50,
#         110, 100, 110, 150,  47, 100, 120,  90, 120, 110, 110, 110, 120,
#         100, 100, 165, 140, 120,  70, 100, 210, 100,  90, 120, 110, 250,
#          90, 220, 100, 160, 250, 110, 110,  90, 120, 155, 110, 100, 110,
#         100, 100, 100, 110, 140, 100, 110, 100, 110, 140, 110, 110, 100,
#         100,  82,  90, 120, 100, 110, 120, 100,  90, 130, 110,  50, 120,
#         110, 120], dtype=int64),
#  array([110, 155,  70, 150,  90, 110, 130, 120, 207, 110, 100, 100,  95,
#         150, 110, 160, 110, 110, 110, 193, 150], dtype=int64))
